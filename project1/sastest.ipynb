# %%
import pandas as pd

lab = pd.read_sas('/Users/konstantingeneralov/IDE/Data/BIOPRO_J.xpt.txt', format='xport', encoding='utf-8')
display(lab.head(), lab.info(), lab.describe(include='all'))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6401 entries, 0 to 6400
# Data columns (total 41 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SEQN      6401 non-null   float64
#  1   LBXSATSI  5902 non-null   float64
#  2   LBDSATLC  5902 non-null   float64
#  3   LBXSAL    5905 non-null   float64
#  4   LBDSALSI  5905 non-null   float64
#  5   LBXSAPSI  5903 non-null   float64
#  6   LBXSASSI  5882 non-null   float64
#  7   LBXSC3SI  5901 non-null   float64
#  8   LBXSBU    5901 non-null   float64
#  9   LBDSBUSI  5901 non-null   float64
#  10  LBXSCLSI  5904 non-null   float64
#  11  LBXSCK    5899 non-null   float64
#  12  LBXSCR    5903 non-null   float64
#  13  LBDSCRSI  5903 non-null   float64
#  14  LBXSGB    5901 non-null   float64
#  15  LBDSGBSI  5901 non-null   float64
#  16  LBXSGL    5901 non-null   float64
#  17  LBDSGLSI  5901 non-null   float64
#  18  LBXSGTSI  5902 non-null   float64
# ...

# %%
#death = pd.read_csv('/Users/konstantingeneralov/IDE/Data/NHANES_III_MORT_2019_PUBLIC.dat', sep="\t")
colspecs = [
    (0,5),   # SEQN
    (6,6),   # ELIGSTAT
    (7,7),   # MORTSTAT
    (8,11),  # MORTDODY
    (12,13), # MORTDODM
    (14,14), # MORTDODQ
    (15,18), # PERMTH_EXM
    (19,22), # PERMTH_INT
]

names = [
    "SEQN","ELIGSTAT","MORTSTAT","MORTDODY","MORTDODM","MORTDODQ","PERMTH_EXM","PERMTH_INT"
]

death = pd.read_fwf('/Users/konstantingeneralov/IDE/Data/NHIS_2018_MORT_2019_PUBLIC.dat', colspecs=colspecs, names=names)

display(death.head()); death.info(); display(death.describe(include='all'))
# Out:
#     SEQN  ELIGSTAT  MORTSTAT  MORTDODY  MORTDODM  MORTDODQ PERMTH_EXM  \
# 0  20180       NaN       NaN        10         0       NaN          0
# 1  20180       NaN       NaN        40         0       NaN          .
# 2  20180       NaN       NaN        60         0       NaN          0
# 3  20180       NaN       NaN        60         0       NaN          .
# 4  20180       NaN       NaN        80         0       NaN          0
#
#   PERMTH_INT
# 0        ...
# 1        ...
# 2        ...
# 3        ...
# 4        ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33686 entries, 0 to 33685
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SEQN        33686 non-null  int64
#  1   ELIGSTAT    0 non-null      float64
#  2   MORTSTAT    0 non-null      float64
#  3   MORTDODY    33686 non-null  int64
#  4   MORTDODM    33686 non-null  int64
#  5   MORTDODQ    0 non-null      float64
# ...
